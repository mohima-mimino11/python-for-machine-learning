# %%
phone_number = 224234
print(phone_number)
# Out:
# 224234

# %%
name = "nemo"
print(name)
# Out:
# nemo

# %%
name="dazai"
age=25
height = 6.5
is_passed = True
print(type(name), type(age), type(height), type(is_passed))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
age = 21.5
print(type(age))
# Out:
# <class 'float'>
